# %% [markdown]
# <a href="https://colab.research.google.com/github/hiranshree/AIML/blob/main/20211CCS0153_LABSHEET3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('/content/empdata.csv')
df.head()
# Out:
#    Empid           Ename    Salary         DOJ
# 0   1001          Ganesh   1000.00  10-10-2000
# 1   1002            Anil  23000.50   3/20/2002
# 2   1003          Gaurav       NaN  03-03-2002
# 3   1004    Hema Chandra  16500.50  09-10-2000
# 4   1005  Laxmi Prasanna  12000.75  10-08-2000

# %%
df.tail(2)
# Out:
#    Empid           Ename    Salary         DOJ
# 4   1005  Laxmi Prasanna  12000.75  10-08-2000
# 5   1006          Anant    9999.99  09-09-1999

# %%
df.head(2)
# Out:
#    Empid   Ename   Salary         DOJ
# 0   1001  Ganesh   1000.0  10-10-2000
# 1   1002    Anil  23000.5   3/20/2002

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Empid   6 non-null      int64
#  1   Ename   6 non-null      object
#  2   Salary  5 non-null      float64
#  3   DOJ     6 non-null      object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 320.0+ bytes

# %%
df.describe()
# Out:
#              Empid        Salary
# count     6.000000      5.000000
# mean   1003.500000  12500.348000
# std       1.870829   8139.622234
# min    1001.000000   1000.000000
# 25%    1002.250000   9999.990000
# 50%    1003.500000  12000.750000
# 75%    1004.750000  16500.500000
# max    1006.000000  23000.500000

# %%
df.shape
# Out:
# (6, 4)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # To retrive columns name

# %%
df.columns
# Out:
# Index(['Empid', 'Ename', 'Salary', 'DOJ'], dtype='object')

# %% [markdown]
# # To retrive column data

# %%
df.Empid
# Out:
# 0    1001
# 1    1002
# 2    1003
# 3    1004
# 4    1005
# 5    1006
# Name: Empid, dtype: int64

# %% [markdown]
# # To retrive a set of columns

# %%
df[['Empid','Ename']]
# Out:
#    Empid           Ename
# 0   1001          Ganesh
# 1   1002            Anil
# 2   1003          Gaurav
# 3   1004    Hema Chandra
# 4   1005  Laxmi Prasanna
# 5   1006          Anant

# %%
df[['Salary','Ename']]
# Out:
#      Salary           Ename
# 0   1000.00          Ganesh
# 1  23000.50            Anil
# 2       NaN          Gaurav
# 3  16500.50    Hema Chandra
# 4  12000.75  Laxmi Prasanna
# 5   9999.99          Anant

# %%
df[['Empid','DOJ','Ename']]
# Out:
#    Empid         DOJ           Ename
# 0   1001  10-10-2000          Ganesh
# 1   1002   3/20/2002            Anil
# 2   1003  03-03-2002          Gaurav
# 3   1004  09-10-2000    Hema Chandra
# 4   1005  10-08-2000  Laxmi Prasanna
# 5   1006  09-09-1999          Anant

# %% [markdown]
# # Check for duplicates and remove them

# %%
df1 = df.append(df)
print('Dimensions of the original frame', df.shape)
print('Dimensions of the frame with duplicates', df1.shape)
df1 = df1.drop_duplicates()
print('Dimensions of the frame after removing duplicates', df1.shape)
# Out:
# Dimensions of the original frame (6, 4)
# Dimensions of the frame with duplicates (12, 4)
# Dimensions of the frame after removing duplicates (6, 4)
# <ipython-input-17-7de3ffc1de87>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1 = df.append(df)

# %%
df.columns = [i.upper() for i in df]
print(df.columns)
# Out:
# Index(['EMPID', 'ENAME', 'SALARY', 'DOJ'], dtype='object')

# %% [markdown]
# # Handling missing values

# %%
df.isna().sum()
df.isnull().sum
print(df.isnull())
print('The no. of nulls in each column is \n', df.isnull().sum())
df.dropna(axis= 1, inplace= False)
# Out:
#    EMPID  ENAME  SALARY    DOJ
# 0  False  False   False  False
# 1  False  False   False  False
# 2  False  False    True  False
# 3  False  False   False  False
# 4  False  False   False  False
# 5  False  False   False  False
# The no. of nulls in each column is
#  EMPID     0
# ENAME     0
# SALARY    1
# DOJ       0
# dtype: int64
#    EMPID           ENAME         DOJ
# 0   1001          Ganesh  10-10-2000
# 1   1002            Anil   3/20/2002
# 2   1003          Gaurav  03-03-2002
# 3   1004    Hema Chandra  09-10-2000
# 4   1005  Laxmi Prasanna  10-08-2000
# 5   1006          Anant   09-09-1999

# %%
df.isna().sum()
#df.isnull().sum
#print(df.isnull())
print('The no. of nulls in each column is \n', df.isnull().sum())
df.dropna(axis= 1, inplace= False)
# Out:
# The no. of nulls in each column is
#  EMPID     0
# ENAME     0
# SALARY    1
# DOJ       0
# dtype: int64
#    EMPID           ENAME         DOJ
# 0   1001          Ganesh  10-10-2000
# 1   1002            Anil   3/20/2002
# 2   1003          Gaurav  03-03-2002
# 3   1004    Hema Chandra  09-10-2000
# 4   1005  Laxmi Prasanna  10-08-2000
# 5   1006          Anant   09-09-1999

# %%
df.isna().sum()
# Out:
# EMPID     0
# ENAME     0
# SALARY    1
# DOJ       0
# dtype: int64

# %%
df
# Out:
#    EMPID           ENAME    SALARY         DOJ
# 0   1001          Ganesh   1000.00  10-10-2000
# 1   1002            Anil  23000.50   3/20/2002
# 2   1003          Gaurav       NaN  03-03-2002
# 3   1004    Hema Chandra  16500.50  09-10-2000
# 4   1005  Laxmi Prasanna  12000.75  10-08-2000
# 5   1006          Anant    9999.99  09-09-1999

# %% [markdown]
# # Find the highest and lowest salary

# %%
print('Highest Salary is', df['SALARY'].max())
print('Lowest Salary is', df['SALARY'].min())
# Out:
# Highest Salary is 23000.5
# Lower Salary is 1000.0

# %%
df[df.SALARY > 20000]
# Out:
#    EMPID ENAME   SALARY        DOJ
# 1   1002  Anil  23000.5  3/20/2002

# %%
df[df.SALARY < 20000]
# Out:
#    EMPID           ENAME    SALARY         DOJ
# 0   1001          Ganesh   1000.00  10-10-2000
# 3   1004    Hema Chandra  16500.50  09-10-2000
# 4   1005  Laxmi Prasanna  12000.75  10-08-2000
# 5   1006          Anant    9999.99  09-09-1999

# %%
df[['EMPID', 'ENAME']] [df.SALARY > 20000]
# Out:
#    EMPID ENAME
# 1   1002  Anil

# %%
df[['EMPID', 'ENAME']] [df.SALARY < 20000]
# Out:
#    EMPID           ENAME
# 0   1001          Ganesh
# 3   1004    Hema Chandra
# 4   1005  Laxmi Prasanna
# 5   1006          Anant

# %% [markdown]
# # Display the Eid and name of the highest paid employee

# %%
print('Average Salary is', df.SALARY.mean())
df['ENAME'][df.SALARY > df.SALARY.mean()]
# Out:
# Average Salary is 12500.348
# 1            Anil
# 3    Hema Chandra
# Name: ENAME, dtype: object

# %%
print('Average Salary is', df.SALARY.mean())
df['ENAME'][df.SALARY < df.SALARY.mean()]
# Out:
# Average Salary is 12500.348
# 0            Ganesh
# 4    Laxmi Prasanna
# 5            Anant
# Name: ENAME, dtype: object

# %% [markdown]
# # Sort in ascending order of DOJ and store the result in another frame

# %%
df1['DOJ'] = pd.to_datetime(df1['DOJ'])
df1.info()
print('Frame before sorting\n', df1)
df1.sort_values("DOJ", inplace = True)
print("Frame after sorting\n", df1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Empid   6 non-null      int64
#  1   Ename   6 non-null      object
#  2   Salary  5 non-null      float64
#  3   DOJ     6 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(1), object(1)
# memory usage: 240.0+ bytes
# Frame before sorting
#     Empid           Ename    Salary        DOJ
# 0   1001          Ganesh   1000.00 2000-10-10
# 1   1002            Anil  23000.50 2002-03-20
# 2   1003          Gaurav       NaN 2002-03-03
# 3   1004    Hema Chandra  16500.50 2000-09-10
# 4   1005  Laxmi Prasanna  12000.75 2000-10-08
# 5   1006          Anant    9999.99 1999-09-09
# Frame after sorting
#     Empid           Ename    Salary        DOJ
# 5   1006          Anant    9999.99 1999-09-09
# 3   1004    Hema Chandra  16500.50 2000-09-10
# 4   1005  Laxmi Prasanna  12000.75 2000-10-08
# 0   1001          Ganesh   1000.00 2000-10-10
# 2   1003          Gaurav       NaN 2002-03-03
# 1   1002            Anil  23000.50 2002-03-20

# %%
df1.sort_values(by = ['DOJ', 'Salary'], ascending = [False, True], inplace = True)
df1
# Out:
#    Empid           Ename    Salary        DOJ
# 1   1002            Anil  23000.50 2002-03-20
# 2   1003          Gaurav       NaN 2002-03-03
# 0   1001          Ganesh   1000.00 2000-10-10
# 4   1005  Laxmi Prasanna  12000.75 2000-10-08
# 3   1004    Hema Chandra  16500.50 2000-09-10
# 5   1006          Anant    9999.99 1999-09-09
